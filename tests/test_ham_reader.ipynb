# %%
import numpy as np
from vuv_analyzer.core.ham_reader import ham_read_file, ham_reader
# Out:
# Running cells with '.venv (Python 3.14.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/software/vuv-libs-analyzer/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
ydatas = ham_reader("sample-data/10us_30meas_05_Al_alloy_30mJ_Ar_1020mbar.csv")
